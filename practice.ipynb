# %%
import numpy as np
import pandas as pd

from IPython.display import display

# %%
#data summary
url = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
df = pd.read_csv(url, error_bad_lines=False)
df.describe(include='all')
# Out:
#                       record_id  utility_id_ferc1   report_year  \
# count                     29523      29523.000000  29523.000000
# unique                    29523               NaN           NaN
# top     f1_fuel_2006_12_266_1_8               NaN           NaN
# freq                          1               NaN           NaN
# mean                        NaN        118.601836   2005.806050
# std                         NaN         74.178353      7.025483
# min                         NaN          1.000000   1994.000000
# 25%                         NaN         55.000000   2000.000000
# 50%                         NaN        122.000000   2006.000000
# 75%                         NaN        176.000000   2012.000000
# max                         NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=29523, step=1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     29523 non-null  object
#  1   utility_id_ferc1              29523 non-null  int64
#  2   report_year                   29523 non-null  int64
#  3   plant_name_ferc1              29523 non-null  object
#  4   fuel_type_code_pudl           29523 non-null  object
#  5   fuel_unit                     29343 non-null  object
#  6   fuel_qty_burned               29523 non-null  float64
#  7   fuel_mmbtu_per_unit           29523 non-null  float64
#  8   fuel_cost_per_unit_burned     29523 non-null  float64
#  9   fuel_cost_per_unit_delivered  29523 non-null  float64
#  10  fuel_cost_per_mmbtu           29523 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
df.tail()
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 29518    neil simpson ct #1                 gas       mcf          18799.0
# 29519  cheyenne prairie 58%                 gas       mcf         806730.0
# 29520     lange ct facility                 gas       mcf         104554.0
# 29521       wygen 3 bhp 52%                coal       ton         315945.0
# 29522       wygen 3 bhp 52%                 gas       mcf          17853.0
#
#        fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 29518                1.059                       4.78
# ...

# %%
x = " stay safe stay healthy "
p = x[-2:-20:-5]
print(p)
# Out:
# yeta

# %%
display(df)
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
pd.options.display.max_columns = None

# %%
pd.set_option('display.max_columns', None)

# %%
display(df)
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
print(df.sort_values("fuel_qty_burned", ascending=False))
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 1715     f1_fuel_1995_12_27_1_1                27         1995
# 1941     f1_fuel_1995_12_74_0_3                74         1995
# 12855  f1_fuel_2004_12_176_0_13               176         2004
# 22624   f1_fuel_2012_12_56_4_14                56         2012
# 24102   f1_fuel_2013_12_56_4_14                56         2013
# ...                         ...               ...          ...
# 18697   f1_fuel_2009_12_194_6_2               194         2009
# 10343   f1_fuel_2002_12_281_4_5               281         2002
# 21958   f1_fuel_2012_12_132_1_2               132         2012
# 23655  f1_fuel_2013_12_281_3_14               281         2013
# 17139     f1_fuel_2008_12_7_3_7                 7         2008
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 1715    j. m. stuart - tota                coal       ton      555894250.0
# ...

# %%
#slicing
print(df.fuel_qty_burned)
# Out:
# 0         5377489.0
# 1        10486945.0
# 2         2978683.0
# 3         3739484.0
# 4           40533.0
#             ...
# 29518       18799.0
# 29519      806730.0
# 29520      104554.0
# 29521      315945.0
# 29522       17853.0
# Name: fuel_qty_burned, Length: 29523, dtype: float64

# %%
df[2:4]
# Out:
#                record_id  utility_id_ferc1  report_year plant_name_ferc1  \
# 2  f1_fuel_1994_12_2_0_1                 2         1994           gorgas
# 3  f1_fuel_1994_12_2_0_7                 2         1994            barry
#
#   fuel_type_code_pudl fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 2                coal       ton        2978683.0                24.13
# 3                coal       ton        3739484.0                23.95
#
#    fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# 2                      39.72                         38.12
# 3                      47.21                         45.99
#
#    fuel_cost_per_mmbtu
# 2                 1.65
# 3                 1.97

# %%
df[["plant_name_ferc1" , "fuel_qty_burned"]]
# Out:
#            plant_name_ferc1  fuel_qty_burned
# 0                  rockport        5377489.0
# 1      rockport total plant       10486945.0
# 2                    gorgas        2978683.0
# 3                     barry        3739484.0
# 4                 chickasaw          40533.0
# ...                     ...              ...
# 29518    neil simpson ct #1          18799.0
# 29519  cheyenne prairie 58%         806730.0
# 29520     lange ct facility         104554.0
# 29521       wygen 3 bhp 52%         315945.0
# 29522       wygen 3 bhp 52%          17853.0
#
# [29523 rows x 2 columns]

# %%
# location can take multple column, df.loc[from_row:to_row,['column1', 'column2']]
df.loc[:,['plant_name_ferc1','fuel_unit']]
# Out:
#            plant_name_ferc1 fuel_unit
# 0                  rockport       ton
# 1      rockport total plant       ton
# 2                    gorgas       ton
# 3                     barry       ton
# 4                 chickasaw       mcf
# ...                     ...       ...
# 29518    neil simpson ct #1       mcf
# 29519  cheyenne prairie 58%       mcf
# 29520     lange ct facility       mcf
# 29521       wygen 3 bhp 52%       ton
# 29522       wygen 3 bhp 52%       mcf
#
# [29523 rows x 2 columns]

# %%
df.loc[3,['plant_name_ferc1']]
# Out:
# plant_name_ferc1    barry
# Name: 3, dtype: object

# %%
# index location can receive range or list of range
df.iloc[2:4,[0,5]]
# Out:
#                record_id fuel_unit
# 2  f1_fuel_1994_12_2_0_1       ton
# 3  f1_fuel_1994_12_2_0_7       ton

# %%
#filter
df[df.fuel_qty_burned<=200000]
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# 6        f1_fuel_1994_12_2_1_1                 2         1994
# 12       f1_fuel_1994_12_4_0_5                 4         1994
# 14       f1_fuel_1994_12_6_0_2                 6         1994
# 19      f1_fuel_1994_12_6_0_14                 6         1994
# ...                        ...               ...          ...
# 29514   f1_fuel_2018_12_12_0_4                12         2018
# 29515   f1_fuel_2018_12_12_0_7                12         2018
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#           plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 4                chickasaw                 gas       mcf          40533.0
# ...

# %%
min(df)
# Out:
# 'fuel_cost_per_mmbtu'

# %%
df[df['utility_id_ferc1'].isin([2,3,4])]
# Out:
#                     record_id  utility_id_ferc1  report_year  \
# 2       f1_fuel_1994_12_2_0_1                 2         1994
# 3       f1_fuel_1994_12_2_0_7                 2         1994
# 4      f1_fuel_1994_12_2_0_10                 2         1994
# 5      f1_fuel_1994_12_2_0_13                 2         1994
# 6       f1_fuel_1994_12_2_1_1                 2         1994
# ...                       ...               ...          ...
# 26757   f1_fuel_2016_12_2_2_4                 2         2016
# 27736   f1_fuel_2017_12_2_0_1                 2         2017
# 27737   f1_fuel_2017_12_2_1_1                 2         2017
# 29050   f1_fuel_2018_12_2_0_1                 2         2018
# 29051   f1_fuel_2018_12_2_1_1                 2         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 2                    gorgas                coal       ton        2978683.0
# 3                     barry                coal       ton        3739484.0
# ...

# %%
#slicing
df.iloc[2:3]
# Out:
#                record_id  utility_id_ferc1  report_year plant_name_ferc1  \
# 2  f1_fuel_1994_12_2_0_1                 2         1994           gorgas
#
#   fuel_type_code_pudl fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 2                coal       ton        2978683.0                24.13
#
#    fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# 2                      39.72                         38.12
#
#    fuel_cost_per_mmbtu
# 2                 1.65

# %%
df.loc[2,['utility_id_ferc1']]
# Out:
# utility_id_ferc1    2
# Name: 2, dtype: object

# %%
df.loc[:,'fuel_qty_burned'] = np.array([5] * len(df))

# %%
# renaming column
df.rename(columns = {'utility_id_ferc1' : 'qty_no'}, inplace = True)

# %%
df.head()#fuel_cost_per_unit_burned 	fuel_cost_per_unit_delivered
# Out:
#                 record_id  qty_no  report_year      plant_name_ferc1  \
# 0   f1_fuel_1994_12_1_0_7       1         1994              rockport
# 1  f1_fuel_1994_12_1_0_10       1         1994  rockport total plant
# 2   f1_fuel_1994_12_2_0_1       2         1994                gorgas
# 3   f1_fuel_1994_12_2_0_7       2         1994                 barry
# 4  f1_fuel_1994_12_2_0_10       2         1994             chickasaw
#
#   fuel_type_code_pudl fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 0                coal       ton        5377489.0               16.590
# 1                coal       ton       10486945.0               16.592
# 2                coal       ton        2978683.0               24.130
# 3                coal       ton        3739484.0               23.950
# 4                 gas       mcf          40533.0                1.000
#
#    fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# 0                      18.59                         18.53
# ...
